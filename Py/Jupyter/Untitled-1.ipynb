# %%
my_string = 'abcdefghijklmnopqrstuvwxyz'

# %%
my_string[1:3]
# Out:
# 'bc'

# %%
my_string[::3]
# Out:
# 'adgjmpsvy'

# %%
len(my_string)
# Out:
# 26

# %%
x =  f'hello { my_string }'

# %%
x
# Out:
# 'hello abcdefghijklmnopqrstuvwxyz'
